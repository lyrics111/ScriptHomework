# %% [markdown]
# ### HomeWork #2
# ### 2019136149 박건우

# %% [markdown]
# ##### 1. 다음 6 개의 Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오
#
# 1 and 2 and 3 and 4
# 1 or 2 or 3 or 4
# 1 and 2 or 3 and 4
# (1 and 2) or (3 and 4)
# 1 or 2 and 3 or 4
# (1 or 2) and (3 or 4)

# %%
print (1 and 2 and 3 and 4)
# Out:
# 4

# %% [markdown]
# and연산의 경우는 앞의것이 참이여도 뒤에것이 참인지 아닌지를 확인해야한다.
# 1 and 2 and 3 and 4 의경우는 1이 참인지 아닌지 확인하고, 그다음 2를 확인하고, 3을확인하고, 마지막으로 4를 확인한 후에 4를 출력한 모습이다.

# %%
print (1 or 2 or 3 or 4)
# Out:
# 1

# %% [markdown]
# or연산의 경우 A or B가 있을 때 A가 참이면은 뒤에있는 B를 볼필요가 없다.
# 위의 표현식의 경우는 앞에있는 1이 참을 의미하므로 뒤에있는 것들을 굳이 체크할 필요가 없으므로 1이 출력된다.

# %%
print (1 and 2 or 3 and 4)
# Out:
# 2

# %% [markdown]
# 파이썬의 연산자 우선순위를 살펴보면 and가 or보다 우선순위에 있다.
# 따라서 먼저 1 and 2 연산을 수행한다.(2 리턴) 그리고 3 and 4 연산을 수행해서 참이 나온다. (4 리턴)
#
# 그다음에는 1 and 2와 3 and 4를 묶어서 or 연산을 수행 해야한다.
# 그런데 이 과정에서 (1 and 2)가 참이므로 or 뒷부분을 체크할 필요가 없다. 따라서 2가 나오게된다.

# %%
print ((1 and 2) or (3 and 4))
# Out:
# 2

# %% [markdown]
# 3번째 케이스와 같은 이유이다.
# 괄호가 붙었지만 어차피 and연산이 or보다 우선순위에 있으므로 결국 연산을 처리하는 순서에는 차이가 없다.
# 똑같이 (1 and 2)연산을 수행하고 (3 and 4)연산을 수행한다.
# 그리고 이 두 연산을 or로 묶는과정에서 앞에있는 (1 and 2)연산이 참이므로 뒤에있는 (3 and  4)연산을 체크할 필요가 없고 따라서 2가 나온다.

# %%
print (1 or 2 and 3 or 4)
# Out:
# 1

# %% [markdown]
# 연산자 우선순위에 의해 2 and 3 연산을 먼저 수행한다 (3리턴)
# and 연산이 모두 끝낫으므로 이제 남은것은 or연산이다.
# 그런데 연산이 1 or로 시작하므로 or 뒷부분을 체크할 필요가 없다
# 따라서 1이 출력된다.

# %%
print ((1 or 2) and (3 or 4))
# Out:
# 3

# %% [markdown]
# 괄호에 충실하게 연산을 수행하면된다.
# 먼저 (1 or 2)에서 1이 리턴되고,  (3 or 4)에서 3이 리턴된다.
# and연산은 앞의값이 참이더라도 뒤에값을 체크해야하므로 3을 출력한다.

# %% [markdown]
# ##### 2. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
#
# * 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
# * 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
# * 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
# * 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     * div_path('/usr/local/bin/python')
#         * ['/usr/local/bin', 'python']
#     * div_path('/home/chulsoo/test.txt')
#         * ['/home/chulsoo', 'test.txt']
# * [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.

# %%
def div_path(s) :
    result = []
    idx = 0;     ## 마지막에 나오는 /의 인덱스를 저장하는 변수 
    for i in range(len(s)):
        if (s[i] == '/'):
            idx = i
    
    result.append(s[0:idx])
    result.append(s[idx+1:len(s)])
    return result

# %%
div_path('/usr/local/bin/python')
# Out:
# ['/usr/local/bin', 'python']

# %%
div_path('/home/chulsoo/test.txt')
# Out:
# ['/home/chulsoo', 'test.txt']

# %% [markdown]
# ##### 3. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
# * 집합 자료형 set은 사용하지 않는다.
# * 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
# * 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
# * 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
# * 반환하는 리스트는 정렬이 되어 있어야 한다.
# * 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     * list_union([1, 2, 3], [1, 2, 4])
#         * [1, 2, 3, 4]
#     * list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#         * [-10, -5, -1, 0, 9, 100]
#     * list_union([0, 1, 2], [0, 1, 2])
#         * [0, 1, 2]
# * [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
# * [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.

# %%
def list_union(lista, listb) :
    result = []
    
    for i in range (len(lista)):   ## 먼저 lista의 원소를 result리스트에 넣자.
        result.append(lista[i])
    
    for i in range (len(listb)):   ## listb의 원소가 이미 result리스트에 있으면 그 원소는 넣지않는다. 그 외의 케이스만 원소를 넣는다.
        if (listb[i] in result):
            continue
        else :
            result.append(listb[i])
    
    result.sort()   ##정렬    
    return result

# %%
list_union([1, 2, 3], [1, 2, 4])
# Out:
# [1, 2, 3, 4]

# %%
list_union([-10, -5, 0, -1], [100, 9, 0, 9])
# Out:
# [-10, -5, -1, 0, 9, 100]

# %%
list_union([0, 1, 2], [0, 1, 2])
# Out:
# [0, 1, 2]

# %% [markdown]
# ##### 4. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '교집합'을 반환하는 함수 list_intersection(lista, listb)와 '차집합'을 반환하는 함수 list_difference(lista, listb)를 작성하시오.
#
# * 모든 가정과 조건은 3번 문제와 동일하다.

# %%
def list_intersection(lista, listb) :
    result = []
    
    for i in range (len(lista)):   ## 먼저 똑같이 lista의 원소를 result리스트에 넣자.
        result.append(lista[i])
        
    for i in range (len(listb)):   ## listb의 원소가 이미 result리스트에 있으면 그 원소를 삭제한다.
        if (listb[i] in result):
            result.remove(listb[i])
    
    
    result.sort()   ## 정렬
    return result

# %%
list_intersection([1, 2, 3], [1, 2, 4])
# Out:
# [3]

# %%
list_intersection([-10, -5, 0, -1], [100, 9, 0, 9])
# Out:
# [-10, -5, -1]

# %%
list_intersection([0, 1, 2], [0, 1, 2])
# Out:
# []

# %% [markdown]
# ##### 5. 두 개의 양의 정수를 인자로 받아서 해당 범위안에 있는 소수(prime number)의 리스트를 출력하는 함수 print_primenumber(a, b)를 작성하시오.
# * 이미 구현된 모듈이나 라이브러리는 사용하지 않는다.
# * 함수의 반환(return)은 없으며 함수 내의 끝에서 .format()을 사용하여 다음과 같이 출력한다.
#     * print_primenumber(2, 10)
#         * 2 이상 10 이하 정수 중 소수 리스트: [2, 3, 5, 7]

# %%
def print_primenumber(a,b) :
    judge = 0
    prime_list = []


    if a < b :
        for i in range (a, b+1) :   
            for j in range (2, i) :
                if (i % j == 0) :
                    judge += 1
                    break;

            if judge == 0 :   ## judge가 0 이면 소수이다.
                prime_list.append(i)

            judge = 0

    else:
        for i in range (b, a+1) :   
            for j in range (2, i) :
                if (i % j == 0) :
                    judge += 1
                    break;

            if judge == 0 :   ## judge가 0 이면 소수이다.
                prime_list.append(i)

            judge = 0

    
    
    output_str = '{}이상 {}이하 정수중 소수리스트: {}'
    print(output_str.format(a,b,prime_list))

# %%
print_primenumber(14, 9)

# %%
print_primenumber(11, 35)

# %%
print_primenumber(17, 17)

# %% [markdown]
# 소수의 정의에 충실해서 해결하면 된다.
# 소수는 2부터 자기자신 -1까지를 나눴을 때 나누어 떨어지지 않는 수이다.
# 이 내용을 for문을 이용해서 코딩하면 된다.
# judge 변수를 0으로 초기화 한 후 나누어떨어질 때는 judge +=1을 넣어서 소수가 아닐때를 특정하고
# 마지막에 judge가 0인 케이스만 따로 떼어내면 된다

# %% [markdown]
# ### [Incremental Project 문제]¶

# %% [markdown]
# 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그를 제외한 순수 텍스트 문자열만을 걸러내고, 2) 그 순수 텍스트 문자열 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.

# %%
import requests
req = requests.get('http://link.koreatech.ac.kr/')
source = req.text

# %%
## HTML태그를 뺀 문자열을 걸러내는 함수 생성
def get_pure_text (str) :
    HTML_flag = False
    style_flag = False
    script_flag = False

    judge = [HTML_flag , style_flag, script_flag]
    result = ''

    for i in range (len(str)):

        if str[i] == '<' :
            judge[0] = True
                
         # i=0일때 i-1이 안될거라 생각했는데 생각해보니 파이썬에서 str[-1]은 가장 뒤의 인덱스다. 따라서 에러가 뜨지않는다.
                
        if str[i-1] == '>' and str[i] != '<':
            judge[0] = False

        if str[i:i+6] == '<style' :
            judge[1] = True

        if str[i:i+8] == '</style>' :
            judge[1] = False
        
        if str[i:i+7] == '<script' :
            judge[2] = True
        
        if str[i:i+9] == '</script>' :
            judge[2] = False

        if True in judge :    ## 만약에 하나의 Flag라도 True를 나타낸다면 문자열을 대입하지않는다
            continue

        result += str[i]
        
    return result

## 공백을 기준으로 문자열의 단어를 세는 함수 생성
def word_count (str) :
    count = 0 ## 단어의 갯수를 세는 변수
    
     ## 공백이 연속된 경우를 방지하기위해 조건을 두개를 건다. 
     ## i-1부터 시작하기때문에 range 범위도 0부터가 아닌 1부터시작한다.
        
        
    for i in range (1, len(str)):
        if str[i-1] != ' ' and str[i] == ' ' :  ## 공백이 아닌문자와 공백문자가 연이어서 있는걸 포착했을 때 단어하나로 카운트
            count += 1
        
    if str[len(str)-1] == ' ' :    ## 맨 마지막에 공백이있으면 단어갯수가 하나 더 카운트 되므로 1줄여야한다.
        count -= 1
        
    return count+1

# %%
#print(source)

# %%
pure_source = get_pure_text(source)

# %%
print (pure_source)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          한국기술교육대학교 LINK 연구실
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     LINK@KOREATECH
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 About
#
#                                         Introduction
#                                         Location
#
#
#                                 Members
#
#                                         Professor
#                                         Current Students/Members
#                                         Alumni
#
#
#                                 Publications
#
#                                         Papers
#                                         Patents
#                                         Standards
#
#
#
#
#                                 Research
#
#                                         Research Areas
# ...

# %%
print (word_count (pure_source)) # 단어 개수 출력
# Out:
# 1385

# %%
req2 = requests.get('http://www.naver.com/')
source2 = req2.text

# %%
#print(source2)

# %%
pure_source2 = get_pure_text(source2)

# %%
print(pure_source2)
# Out:
#                              NAVER                                                뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기
#
#
#
# NAVER whale
#
#
# 눈의 피로감을 줄이는 다크 모드! 지금 적용해보기
# 다운로드
# 3일 동안 보지 않기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 네이버를 시작페이지로
#
# 쥬니어네이버
# 해피빈
#
#
#
#
#
# 검색
#
# 통합검색블로그카페- 카페명- 카페글지식iN뉴스사이트- 카테고리- 사이트영화웹문서사전- 백과사전- 영어사전- 영영사전- 국어사전- 일본어사전- 한자사전- 용어사전책음악전문자료쇼핑지역동영상이미지내PC영화자동차게임건강인물긍정부정검색
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
#
# 한글 입력기
#
#
#
# 자동완성 레이어
#
#
#
#
#
#
#
#
#
#
#
# 최근검색어
#
#
# 전체삭제
#
#
#
#
#
#
#
#
#
#
# @txt@
#
#
# @date@.
#
# 삭제
#
#
#
#
#
# 검색어 저장 기능이 꺼져 있습니다.설정이 초기화 된다면 도움말을 확인해주세요.
#
#
# 최근 검색어 내역이 없습니다.설정이 초기화 된다면 도움말을 확인해주세요.
#
#
#
# 도움말
#
#
#
#
# 자동저장 끄기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# @5@회차 당첨번호
#
# 추첨 @13@.지급기한 1년
#
#
#
#
# @6@@7@@8@@9@@10@@11@@12@
#
#
#
#
#
#
#
#
#
#
#
# @14@
#
# @txt@@currency@
#
# @8@(@9@%)
#
#
#
# @6@원
#
#
#
#
#
#
#
#
#
#
#
# @txt@
#
# @7@, @message@
#
#
#
#
#
# @7@
# @8@°
#
#
# ...

# %%
print (word_count (pure_source2)) # 단어 개수 출력
# Out:
# 2641

# %% [markdown]
# Incremental Project의 첫 번째 문제(순수 문자열 추출하기)를 해결하기 위해서 flag를 담은 list를 이용했다.
# list에있는 flag중에 하나라도 True인게 있다면 Continue문을 이용해서 문자열을 추출하는 부분을 건너뛰도록 했다.
# 특정한 문자열 사이에있는 부분을 걸러내기 위해서 이런 방법을 사용했다.
# 예를들어 <script과 사이에 </script>있는 문자를 걸러내기위해서 <script를 마주치면 flag가 True </script>를 다시 마주하면 flag가 False가되는 방식이다.
#
# 두 번째 문제 (단어 갯수 세기)는 공백문자가 연이어서 나올때를 반드시 고려해야한다.
# 애초에 순수 문자열을 추출했을때 연이어서 나오는 공백이 너무 많기때문에 이 케이스를 배제하면 안 된다.
# 그래서 그부분을 신경써서 풀었다.

# %% [markdown]
# ## 소감
#
# 마지막에 순수문자열을 얻어내는 문제를 풀면서 고생을 좀 했다. 그 나머지 문제 푼 시간보다 순수 문자열 얻어내는 함수 짜는데 걸린 시간이 훨씬 긴 것 같다. 처음에 꺽쇠괄호만 대충 걸러내면 되겠지 라는 생각으로 했는데, 순수문자열이 아닌 부분이 너무 많이나와서 당황했다. 웹 페이지 소스에 대한 지식이 없어서 flag를 몇 개나 만들어야 할지 감이 오지 않았다. 그런데 차근차근 읽어보니 style하고 script만 걸러내면 되었다. 지금에서야 style은 css고 script는 자바스크립트 코드를 의미한다는 것을 알게 되었다. 힘들게 하고나니 마지막에 순수 문자열만 걸러졌을 때 너무 기뻣다.
#
# flag를 리스트에 저렇게 담아쓰는게 좋은코드인지 잘 모르겠다. 지금은 flag가 3개라 다행이지만 만약 flag를 엄청 많이 생성해야 한다면 문제요소가 있을 것 같다. 어떤 flag가 몇 번 index인지 계속 확인을 해야 하니 더 복잡해 질 수 있고, flag를 삭제할때 인덱스가 엉망이 될 지도 모르겠다는 생각이 들었다.
